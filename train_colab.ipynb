# %%
# !git clone https://github.com/A-n-i-e/Final-Year-Project-Runs.git
# %cd Final-Year-Project-Runs
# Out:
# Failed to connect to the remote Jupyter Server 'https://8080-gpu-t4-s-kkb-usw1b2-2tb8gl01v401m-b.us-west1-2.prod.colab.dev/'. Verify the server is running and reachable. (Failed to connect to the remote Jupyter Server 'https://8080-gpu-t4-s-kkb-usw1b2-2tb8gl01v401m-b.us-west1-2.prod.colab.dev/'. Verify the server is running and reachable. (request to https://8080-gpu-t4-s-kkb-usw1b2-2tb8gl01v401m-b.us-west1-2.prod.colab.dev/api/kernels?1780578619522 failed, reason: socket hang up).).

# %% [markdown]
# <a href="https://colab.research.google.com/github/A-n-i-e/Final-Year-Project-Runs/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -r requirements.txt

# %%
# !python train.py \
    --algo SAC \
    --timesteps 1000000 \
